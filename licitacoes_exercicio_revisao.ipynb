# %% [markdown]
# # 3.5 (Parte1) - Exercício de Revisão | Funções

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/PROGRAMARIA/MÓDULO 03/licitacoes.csv',encoding="latin1", sep=";")

# %%
df.head()
# Out:
#    Número Licitação  Código UG                                       Nome UG  \
# 0             12016     160438     COMANDO 2 BRIGADA DE CAVALARIA MECANIZADA
# 1             12017     160203       2º BATALHAO DE ENGENHARIA DE CONSTRUCAO
# 2             12017     193002  DEPARTAMENTO NACIONAL DE OBRAS CONT.AS SECAS
# 3             12018     925135              BANCO CENTRAL DO BRASIL - RECIFE
# 4             12018     110101     GABINETE DA VICE-PRESIDENCIA DA REPUBLICA
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                       -99    Pregão - Registro de Preço  80871182401201629
# 1                         3                  Concorrência  64040053530201713
# 2                         2              Tomada de Preços  59400003079201636
# 3                         6         Dispensa de Licitação             148097
# 4                         7  Inexigibilidade de Licitação  00300000433201818
#
# ...

# %%
df[df['Situação Licitação']!='Encerrado']
# Out:
#        Número Licitação  Código UG  \
# 0                 12016     160438
# 1                 12017     160203
# 2                 12017     193002
# 4                 12018     110101
# 5                 12018     110102
# ...                 ...        ...
# 15316         904842018     150232
# 15330         908292018     154040
# 15331         920182018     135023
# 15332         924192017     158274
# 15335         996252018     153035
#
#                                             Nome UG  Código Modalidade Compra  \
# 0         COMANDO 2 BRIGADA DE CAVALARIA MECANIZADA                       -99
# 1           2º BATALHAO DE ENGENHARIA DE CONSTRUCAO                         3
# 2      DEPARTAMENTO NACIONAL DE OBRAS CONT.AS SECAS                         2
# 4         GABINETE DA VICE-PRESIDENCIA DA REPUBLICA                         7
# 5      SUPERINTENDENCIA REG. DE ADMIN. DA 2ª REGIAO                         7
# ...

# %%
df['Situação Licitação'].value_counts()
# Out:
# Situação Licitação
# Encerrado                         9016
# Publicado                         3709
# Evento de Resultado de Julgame    1922
# Retificação                        127
# Evento de Alteração Publicad        93
# Evento de Suspensão Publicado       72
# Anulação                            67
# Revogação                           63
# Divulgado                           55
# Evento de Adiamento Publicado       46
# Evento de Retificação Public        45
# Evento de Revogação Publicad        40
# Evento de Alteração de Resul        37
# Evento de Anulação Publicado        18
# Evento de Retificação Divulg         7
# Inválido                             4
# Evento de Habilitação Public         4
# Evento de Alteração Divulgad         4
# Evento de Reabertura de Prazo        4
# Evento de Adiamento Divulgado        3
# Name: count, dtype: int64

# %% [markdown]
# DICA DE UMA ALUNA: A: Retorna as linhas onde a situação é "Encerrado", mas não conta quantas são. Para contar, você precisaria usar .shape[0] ou len().

# %%
df['Situação Licitação'].value_counts().shape[0]
# Out:
# 20

# %% [markdown]
# # 4.2 - Faça você mesme | Tratando valores faltantes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15336 entries, 0 to 15335
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Número Licitação          15336 non-null  int64
#  1   Código UG                 15336 non-null  int64
#  2   Nome UG                   15336 non-null  object
#  3   Código Modalidade Compra  15336 non-null  int64
#  4   Modalidade Compra         15336 non-null  object
#  5   Número Processo           15336 non-null  object
#  6   Objeto                    15336 non-null  object
#  7   Situação Licitação        15336 non-null  object
#  8   Código Órgão Superior     15336 non-null  int64
#  9   Nome Órgão Superior       15336 non-null  object
#  10  Código Órgão              15336 non-null  int64
#  11  Nome Órgão                15336 non-null  object
#  12  UF                        15336 non-null  object
# ...

# %%
  df.isnull().sum()
# Out:
# Número Licitação                0
# Código UG                       0
# Nome UG                         0
# Código Modalidade Compra        0
# Modalidade Compra               0
# Número Processo                 0
# Objeto                          0
# Situação Licitação              0
# Código Órgão Superior           0
# Nome Órgão Superior             0
# Código Órgão                    0
# Nome Órgão                      0
# UF                              0
# Município                       0
# Data Resultado Compra           0
# Data Abertura               10648
# Valor Licitação                 0
# dtype: int64

# %%
# Com relação ao dois códigos acima: BATEU: 10.648 + 4688 = 15.336
# # Tem gente que pega a "moda" , acho q data q mais se repete. Outras localizam os campos vazios e substituem por "Não informado".

#Vamos lá:

# Identificando o tipo de dados desta coluna
df['Data Abertura'].dtypes
# Out:
# dtype('O')

# %%
# Substituindo os valores faltantes pelo mesmo formato
df['Data Abertura'] = df['Data Abertura'].fillna('Não Informado')
print(df['Data Abertura'])
# Out:
# 0           17/08/2016
# 1        Não Informado
# 2        Não Informado
# 3           30/11/2018
# 4        Não Informado
#              ...
# 15331       26/11/2018
# 15332    Não Informado
# 15333    Não Informado
# 15334    Não Informado
# 15335    Não Informado
# Name: Data Abertura, Length: 15336, dtype: object

# %%
# Repeti apenas para ver a diferença COM print e SEM print

# Substituindo os valores faltantes pelo mesmo formato
df['Data Abertura'] = df['Data Abertura'].fillna('Não Informado')
df['Data Abertura']
# Out:
# 0           17/08/2016
# 1        Não Informado
# 2        Não Informado
# 3           30/11/2018
# 4        Não Informado
#              ...
# 15331       26/11/2018
# 15332    Não Informado
# 15333    Não Informado
# 15334    Não Informado
# 15335    Não Informado
# Name: Data Abertura, Length: 15336, dtype: object

# %%
# Aqui comprova que foram todos substituídos, pois não retornou nada
df[df['Data Abertura'].isnull()]['Data Abertura'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# PARA REFORÇO
# Como fiz a atribuição, ou seja, a substituição de 10.648 células vazios por "Não Informado", agora é
# o que aparece como o valor moda ao aplicar a consulta de "mode"
#A função mode em Python serve para encontrar o valor mais frequente (ou mais comum) em uma sequência de dados, como uma lista.

df['Data Abertura'].mode()
# Out:
# 0    Não Informado
# Name: Data Abertura, dtype: object
